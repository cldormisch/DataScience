# %%
import pandas as pd
from google.colab import drive
import os
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive'
df= pd.read_excel('Facturación 20-21-22.xls')
print(df[['N_Factura','Remito','Ciudad', 'Vendedor']].head(30))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive
#         N_Factura         Remito              Ciudad     Vendedor
# 0   9036A00004271  0036R00005837         LAS PAREJAS        Mauro
# 1   9036A00004271  0036R00005837         LAS PAREJAS        Mauro
# 2   9036A00004271  0036R00005837         LAS PAREJAS        Mauro
# 3   9036A00004271  0036R00005837         LAS PAREJAS        Mauro
# 4   9036A00004271  0036R00005837         LAS PAREJAS        Mauro
# 5   9036A00004273  0036R00005839             ROSARIO        Guido
# 6   9036A00004273  0036R00005839             ROSARIO        Guido
# 7   9036A00004269  0036R00005835  VILLA CONSTITUCION        Jorge
# 8   9036A00004269  0036R00005835  VILLA CONSTITUCION        Jorge
# 9   9036A00004277  0036R00005845              PARANA      ANULADO
# 10  9036A00004277  0036R00005845              PARANA      ANULADO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41096 entries, 0 to 41095
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Centro_lucro       41095 non-null  float64
#  1   N_Factura          41096 non-null  object
#  2   Doc_facturacion    41096 non-null  int64
#  3   Remessa            41096 non-null  int64
#  4   Ordem de venda     41051 non-null  float64
#  5   Remito             41052 non-null  object
#  6   TipoDoc_Fact       41096 non-null  object
#  7   FechaFacturacion   41096 non-null  datetime64[ns]
#  8   Org. de vendas     41096 non-null  object
#  9   CanalDistribucion  41096 non-null  int64
#  10  CentroVentas       41096 non-null  object
#  11  EquipoVentas       41096 non-null  object
#  12  SectorActividad    41096 non-null  int64
#  13  Vendedor           40505 non-null  object
#  14  Ciudad             40505 non-null  object
# ...

# %%
print(df.shape)
# Out:
# (41096, 40)
